# %%
import numpy as np
import pandas as pd

import importlib
importlib.reload(utils)
import sys
sys.path.append("../../utils")
import analysis_untilities as utils

# %%
aidata = pd.read_csv("AI Job Market Dataset.csv")

# %%
aidata.head()
# Out:
#    job_id                  job_title company_size company_industry    country  \
# 0       1                AI Engineer      Startup           Retail     Canada
# 1       2  Machine Learning Engineer          MNC       Technology  Australia
# 2       3  Machine Learning Engineer          MNC       Technology    Germany
# 3       4           Business Analyst      Startup       Healthcare    Germany
# 4       5             Data Scientist          MNC       Healthcare    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
# 3      Remote              Mid                 9          Master
# 4      Hybrid              Mid                 5          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# ...

# %%
importlib.reload(utils)
utils.overview(aidata)
# Out:
# No.Rows: 10345
# No.Columns: 19
# Columns:
#   - job_id                  (10345 Uniques) (0 nulls)  int64
#   - job_title               (6 Uniques)     (0 nulls)  object
#   - company_size            (4 Uniques)     (0 nulls)  object
#   - company_industry        (6 Uniques)     (0 nulls)  object
#   - country                 (7 Uniques)     (0 nulls)  object
#   - remote_type             (3 Uniques)     (0 nulls)  object
#   - experience_level        (3 Uniques)     (0 nulls)  object
#   - years_experience        (15 Uniques)    (0 nulls)  int64
#   - education_level         (3 Uniques)     (0 nulls)  object
#   - skills_python           (2 Uniques)     (0 nulls)  int64
#   - skills_sql              (2 Uniques)     (0 nulls)  int64
#   - skills_ml               (2 Uniques)     (0 nulls)  int64
#   - skills_deep_learning    (2 Uniques)     (0 nulls)  int64
#   - skills_cloud            (2 Uniques)     (0 nulls)  int64
#   - salary                  (9901 Uniques)  (0 nulls)  int64
# ...

# %%
filter_country = aidata.loc[aidata.country=="Australia"]
titles_aus = filter_country.groupby("job_title").size()
titles_aus
# Out:
# job_title
# AI Engineer                  233
# Business Analyst             248
# Data Analyst                 219
# Data Engineer                228
# Data Scientist               275
# Machine Learning Engineer    252
# dtype: int64

# %%
education_aus = filter_country.groupby("education_level").size()
education_aus
# Out:
# education_level
# Bachelor    462
# Master      511
# PhD         482
# dtype: int64

# %%
filter_country_education = aidata.loc[(aidata.country=="Australia") 
                                      & (aidata.education_level=="Bachelor")
                                      & (~aidata.experience_level.isin(["Senior", "Mid"]))
                                      & (aidata.job_posting_year==2026)
                                      ]
filter_country_education
# Out:
#        job_id                  job_title company_size company_industry  \
# 187       188           Business Analyst       Medium        Education
# 1150     1151  Machine Learning Engineer       Medium       E-commerce
# 1485     1486                AI Engineer      Startup           Retail
# 1503     1504  Machine Learning Engineer      Startup       E-commerce
# 2429     2430                AI Engineer          MNC          Finance
# 3330     3331              Data Engineer       Medium       Technology
# 3386     3387             Data Scientist          MNC        Education
# 4069     4070           Business Analyst       Medium          Finance
# 4918     4919              Data Engineer       Medium          Finance
# 4937     4938  Machine Learning Engineer          MNC       E-commerce
# 5241     5242                AI Engineer       Medium       Healthcare
# 5543     5544              Data Engineer      Startup       Technology
# ...

# %%
filter_country_education.job_posting_year.dtypes
# Out:
# dtype('int64')
